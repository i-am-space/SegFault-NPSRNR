# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv('COVID_dataset.csv')
age = df.groupby('Age')['Time of reporting'].count()


fig = plt.figure(figsize=(10, 10))
ax = plt.subplot()
plt.bar(range(0, 90), age, color='#33FF4C')
plt.title('Deaths per Age')
plt.xlabel('Ages')
plt.ylabel('Deaths')
ax.set_xticks(range(0, 90, 10))
ax.set_yticks(range(0,10000,1000))
ax.set_xticklabels([str(i) for i in range(0, 90, 10)], rotation=90)
plt.show()
